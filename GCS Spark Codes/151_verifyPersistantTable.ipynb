# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('Spark Table Verification').getOrCreate()
# Out:
# 25/06/09 04:47:04 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
new_session = spark.newSession()

# %%
new_session.sql('show tables').show()
# Out:
# +---------+--------------------+-----------+
# |namespace|           tableName|isTemporary|
# +---------+--------------------+-----------+
# |  default|customers_persistent|      false|
# +---------+--------------------+-----------+

# %%
# Access the SparkContext and then get the application ID
app_id = spark.sparkContext.applicationId

# Print the app ID
print(f"The application ID is: {app_id}")
# Out:
# The application ID is: application_1749436701339_0007

# %%
spark.sql('describe customers_persistent').show()
# Out:
# +----------+---------+-------+
# |  col_name|data_type|comment|
# +----------+---------+-------+
# |     India|      int|   NULL|
# |2023-10-07|   string|   NULL|
# |     False|   string|   NULL|
# +----------+---------+-------+

# %%
spark.sql('describe extended customers_persistent').show()
# Out:
# +--------------------+--------------------+-------+
# |            col_name|           data_type|comment|
# +--------------------+--------------------+-------+
# |               India|                 int|   NULL|
# |          2023-10-07|              string|   NULL|
# |               False|              string|   NULL|
# |                    |                    |       |
# |# Detailed Table ...|                    |       |
# |             Catalog|       spark_catalog|       |
# |            Database|             default|       |
# |               Table|customers_persistent|       |
# |               Owner|                root|       |
# |        Created Time|Mon Jun 09 04:44:...|       |
# |         Last Access|             UNKNOWN|       |
# |          Created By|         Spark 3.5.3|       |
# |                Type|             MANAGED|       |
# |            Provider|             parquet|       |
# |          Statistics|          3005 bytes|       |
# ...

# %%
# !hdfs dfs -ls /user/hive/warehouse/customers_persistent/
# Out:
# Found 2 items
# -rw-r--r--   2 root hadoop          0 2025-06-09 04:44 /user/hive/warehouse/customers_persistent/_SUCCESS
# -rw-r--r--   2 root hadoop       3005 2025-06-09 04:44 /user/hive/warehouse/customers_persistent/part-00000-8ac46088-c19a-49f0-a114-7f1b17e92cc0-c000.snappy.parquet

# %%
spark.stop()

# %%
new_session.stop()
