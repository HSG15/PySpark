# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('bigCaching').getOrCreate()
# Out:
# 25/06/13 02:54:05 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
df = spark.read.format('csv').option('header', True).option('inferSchema', True).load('/data/customers10.csv')
df.show(5)
# Out:
# +---------+---------------+----------+-----------+
# |Karnataka|          India|2023-10-26|       True|
# +---------+---------------+----------+-----------+
# |   135896|Customer_135896|   Kolkata|    Gujarat|
# |   135897|Customer_135897| Ahmedabad|  Karnataka|
# |   135898|Customer_135898|      Pune|      Delhi|
# |   135899|Customer_135899|     Delhi|West Bengal|
# |   135900|Customer_135900|    Mumbai|      Delhi|
# +---------+---------------+----------+-----------+
# only showing top 5 rows

# %%
df.cache()
# Out:
# DataFrame[Karnataka: int, India: string, 2023-10-26: string, True: string]

# %%
df.show(5)
# Out:
# [Stage 21:>                                                         (0 + 1) / 1]
# +---------+---------------+----------+-----------+
# |Karnataka|          India|2023-10-26|       True|
# +---------+---------------+----------+-----------+
# |   135896|Customer_135896|   Kolkata|    Gujarat|
# |   135897|Customer_135897| Ahmedabad|  Karnataka|
# |   135898|Customer_135898|      Pune|      Delhi|
# |   135899|Customer_135899|     Delhi|West Bengal|
# |   135900|Customer_135900|    Mumbai|      Delhi|
# +---------+---------------+----------+-----------+
# only showing top 5 rows

# %%
spark.sparkContext.applicationId
# Out:
# 'application_1749783134048_0002'

# %%
tail_df = df.orderBy('Karnataka', ascending = False)

# %%
tail_df.show()
# Out:
# +---------+---------------+----------+-----------+
# |Karnataka|          India|2023-10-26|       True|
# +---------+---------------+----------+-----------+
# |   152450|Customer_152450|     Delhi| Tamil Nadu|
# |   152449|Customer_152449|      Pune|    Gujarat|
# |   152448|Customer_152448|   Kolkata| Tamil Nadu|
# |   152447|Customer_152447|   Kolkata|      Delhi|
# |   152446|Customer_152446| Bangalore|Maharashtra|
# |   152445|Customer_152445|   Kolkata|      Delhi|
# |   152444|Customer_152444| Bangalore|      Delhi|
# |   152443|Customer_152443|      Pune|  Karnataka|
# |   152442|Customer_152442| Hyderabad|West Bengal|
# |   152441|Customer_152441|    Mumbai|  Telangana|
# |   152440|Customer_152440|   Chennai|    Gujarat|
# |   152439|Customer_152439| Ahmedabad|Maharashtra|
# |   152438|Customer_152438| Hyderabad|West Bengal|
# |   152437|Customer_152437|   Kolkata|  Karnataka|
# |   152436|Customer_152436| Bangalore|  Telangana|
# ...

# %%
tail_df.show(5)
# Out:
# +---------+---------------+----------+-----------+
# |Karnataka|          India|2023-10-26|       True|
# +---------+---------------+----------+-----------+
# |   152450|Customer_152450|     Delhi| Tamil Nadu|
# |   152449|Customer_152449|      Pune|    Gujarat|
# |   152448|Customer_152448|   Kolkata| Tamil Nadu|
# |   152447|Customer_152447|   Kolkata|      Delhi|
# |   152446|Customer_152446| Bangalore|Maharashtra|
# +---------+---------------+----------+-----------+
# only showing top 5 rows

# %%
df.unpersist()
# Out:
# DataFrame[Karnataka: int, India: string, 2023-10-26: string, True: string]

# %%
spark.stop()
